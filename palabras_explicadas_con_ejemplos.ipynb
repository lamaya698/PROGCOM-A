# %%
# Importar librerías necesarias
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from google.colab import drive, files
import torch
import tensorflow as tf
import time
import zipfile
import shutil
import json
import pickle

# Lista de palabras clave
palabras = [
    '!ls', '!pwd', '!pip install numpy', '!apt-get install figlet', '%timeit', '%matplotlib inline',
    'drive.mount', 'files.upload', 'files.download', 'pd.read_csv', 'pd.DataFrame', 'np.array',
    'np.linspace', 'np.random.rand', 'np.dot', 'torch.tensor', 'torch.cuda.is_available()', 'torch.nn.Linear',
    'tf.Variable', 'tf.constant', 'tf.matmul', 'os.listdir', 'os.getcwd', 'os.remove',
    'cv2.imread', 'cv2.cvtColor', 'cv2.resize', 'plt.plot', 'plt.scatter', 'plt.hist',
    'open()', 'read()', 'write()', 'with open()', 'zipfile.ZipFile', 'shutil.copy',
    'json.load', 'json.dump', 'pickle.load', 'pickle.dump', 'time.sleep', 'enumerate()',
    'map()', 'filter()', 'lambda', 'try-except', 'assert', 'class', 'def', 'return'
]

# Mostrar palabras clave
print("50 palabras clave en Google Colab:")
for i, palabra in enumerate(palabras, 1):
    print(f"{i}. {palabra}")

time.sleep(2)  # Pausa antes de ejecutar ejemplos

# Ejecutar ejemplos
print("\nEjemplo de comandos de sistema:")
# !ls
# !pwd
# !pip install numpy
# !apt-get install figlet

print("\nEjemplo de comandos mágicos:")
# %timeit sum(range(1000))

print("\nEjemplo de Google Drive:")
drive.mount('/content/drive')

print("\nEjemplo de carga y descarga de archivos:")
uploaded = files.upload()
files.download('archivo.txt')

print("\nEjemplo de Pandas:")
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df)

df.to_csv('data.csv')
df_read = pd.read_csv('data.csv')
print(df_read.head())

print("\nEjemplo de NumPy:")
array = np.array([1, 2, 3])
print("Array:", array)

linspace_array = np.linspace(0, 10, 5)
print("Linspace Array:", linspace_array)

rand_array = np.random.rand(3, 3)
print("Random Array:", rand_array)

print("\nEjemplo de PyTorch:")
tensor = torch.tensor([1, 2, 3])
print("Tensor:", tensor)

print("GPU disponible:", torch.cuda.is_available())

print("\nEjemplo de TensorFlow:")
tf_var = tf.Variable([1, 2, 3])
print("TensorFlow Variable:", tf_var)

print("\nEjemplo de OS:")
print("Archivos en directorio actual:", os.listdir())
print("Directorio actual:", os.getcwd())

print("\nEjemplo de OpenCV:")
img = np.zeros((100, 100, 3), dtype=np.uint8)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(img, (50, 50))
print("Imagen procesada con OpenCV")

print("\nEjemplo de Matplotlib:")
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("Gráfica de seno")
plt.show()

print("\nEjemplo de manejo de archivos:")
with open("archivo.txt", "w") as file:
    file.write("Ejemplo de archivo en Google Colab.")

with open("archivo.txt", "r") as file:
    contenido = file.read()
print("Contenido del archivo:", contenido)

print("\nEjemplo de JSON:")
data = {'nombre': 'Colab', 'tipo': 'tutorial'}
with open('data.json', 'w') as f:
    json.dump(data, f)

with open('data.json', 'r') as f:
    loaded_data = json.load(f)
print("Datos JSON:", loaded_data)

print("\nEjemplo de Pickle:")
with open('data.pkl', 'wb') as f:
    pickle.dump(data, f)

with open('data.pkl', 'rb') as f:
    loaded_pickle = pickle.load(f)
print("Datos Pickle:", loaded_pickle)

print("\nEjemplo de funciones avanzadas:")
def cuadrado(x):
    return x**2

nums = [1, 2, 3, 4]
squares = list(map(cuadrado, nums))
print("Cuadrados:", squares)

pares = list(filter(lambda x: x % 2 == 0, nums))
print("Números pares:", pares)

print("\nEjemplo de excepciones:")
try:
    resultado = 10 / 0
except ZeroDivisionError:
    print("Error: División por cero")

print("\nEjemplo de clases:")
class Persona:
    def __init__(self, nombre):
        self.nombre = nombre

    def saludar(self):
        return f"Hola, soy {self.nombre}"

p = Persona("Juan")
print(p.saludar())

print("\nTodos los ejemplos ejecutados con éxito.")
# Out:
# 50 palabras clave en Google Colab:
# 1. !ls
# 2. !pwd
# 3. !pip install numpy
# 4. !apt-get install figlet
# 5. %timeit
# 6. %matplotlib inline
# 7. drive.mount
# 8. files.upload
# 9. files.download
# 10. pd.read_csv
# 11. pd.DataFrame
# 12. np.array
# 13. np.linspace
# 14. np.random.rand
# 15. np.dot
# 16. torch.tensor
# 17. torch.cuda.is_available()
# 18. torch.nn.Linear
# 19. tf.Variable
# 20. tf.constant
# 21. tf.matmul
# 22. os.listdir
# 23. os.getcwd
# 24. os.remove
# 25. cv2.imread
# 26. cv2.cvtColor
# 27. cv2.resize
# 28. plt.plot
# 29. plt.scatter
# 30. plt.hist
# 31. open()
# 32. read()
# 33. write()
# 34. with open()
# 35. zipfile.ZipFile
# 36. shutil.copy
# 37. json.load
# 38. json.dump
# 39. pickle.load
# 40. pickle.dump
# 41. time.sleep
# 42. enumerate()
# 43. map()
# 44. filter()
# 45. lambda
# 46. try-except
# 47. assert
# 48. class
# 49. def
# 50. return
#
# Ejemplo de comandos de sistema:
# 'Cuando el código compila.png'	 drive	 sample_data
# /content
# ...
